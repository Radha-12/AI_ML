# %% [markdown]
# <a href="https://colab.research.google.com/github/Radha-12/AI_ML/blob/main/Applied_Statistics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Applied Statistics Project **

# %% [markdown]
# **▶ PART - A**

# %% [markdown]
# Q1.A)   Create the joint probability of the people who planned to purchase and actually placed an order.

# %%
# PP is the number of people who planned and actually placed an order for Product A
PP = 400
AP  = 2000
JP1 = round(PP / AP,4) 
print('Joint probability of the people who planned to purchase and actually placed an order. is %1.4f' % JP1)
# Out:
# Joint probability of the people who planned to purchase and actually placed an order. is 0.2000

# %% [markdown]
# Joint probability of the people who planned to purchase and actually placed an order. is 0.2000

# %% [markdown]
# B) Create the joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase.

# %%
# P1 = P(Actually placed an order | Planned to purchase) i.e [p2/p3]
# P2 = Planned to purchase and actually placed an order
# P3 = Planned to purchase
P1   = (400 / 2000 )/ (500 / 2000)

print('P(Actually placed an order | Planned to purchase) is %1.4f' % P1)
# Out:
# P(Actually placed an order | Planned to purchase) is 0.8000

# %% [markdown]
# Joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase is 0.8000

# %% [markdown]
# Q2.An electrical manufacturing company conducts quality checks at specified periods on the products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random sample of 10 manufactured items is selected. Answer the following questions
#
# A) Probability that none of the items are defective?

# %%
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt

# %%
p   =  0.05 # failure rate for the product that the electrical manufacturing company is 5%
n   =  10 # sample size
k   =  np.arange(0,11) # An array of quantiles

# %%
binomial = stats.binom.pmf(k,n,p)

# %%
print(binomial)
# Out:
# [5.98736939e-01 3.15124705e-01 7.46347985e-02 1.04750594e-02
#  9.64808106e-04 6.09352488e-05 2.67259863e-06 8.03789062e-08
#  1.58642578e-09 1.85546875e-11 9.76562500e-14]

# %%
print('A) None of the items are defective? is %1.4f' %binomial[0])
# Out:
# A) None of the items are defective? is 0.5987

# %% [markdown]
# Probability that none of the items are defective is 0.5987

# %% [markdown]
# B) Probability that exactly one of the items are defective?

# %%
print('B) None of the items are defective? is %1.4f' %binomial[1])
# Out:
# B) None of the items are defective? is 0.3151

# %% [markdown]
# Probability that exactly one of the items are defective is 0.3151

# %% [markdown]
# C) Probability that two or fewer of the items are defective?

# %% [markdown]
# we need to calculate cumulative probability of Upto Two items being defective

# %%
cumbinomial = stats.binom.cdf(k,n,p)

# %%
print(cumbinomial)
# Out:
# [0.59873694 0.91386164 0.98849644 0.9989715  0.99993631 0.99999725
#  0.99999992 1.         1.         1.         1.        ]

# %%
print('C) Two or fewer of the items are defective? is %1.4f' %cumbinomial[2])
# Out:
# C) Two or fewer of the items are defective? is 0.9885

# %% [markdown]
# Probablity of Two or fewer items are defective is 0.9885

# %% [markdown]
# D) Probability that three or more of the items are defective ?

# %% [markdown]
# we need to subtract cumulative Probability upto 2 defective items from 1.

# %%
P = 1- cumbinomial[2]
print('D) Three or more of the items are defective is %1.4f' % P)
# Out:
# D) Three or more of the items are defective is 0.0115

# %% [markdown]
# Probability of three or more of the items are defective is 0.0115

# %% [markdown]
# Q3. A car salesman sells on an average 3 cars per week.
#
# A) What is Probability that in a given week he will sell some cars?
#
# Here,
#
#  λ(Average number of successes)  = 3

# %%
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt

# %%
rate =  3 # Mean
n    =  np.arange(0,16)
cumpoisson = stats.poisson.cdf(n,rate)

# %%
cumpoisson
# Out:
# array([0.04978707, 0.19914827, 0.42319008, 0.64723189, 0.81526324,
#        0.91608206, 0.96649146, 0.9880955 , 0.99619701, 0.99889751,
#        0.99970766, 0.99992861, 0.99998385, 0.9999966 , 0.99999933,
#        0.99999988])

# %%
# P = probability that the salesman sells some cars
P   = 1 - cumpoisson[0]
print(' A) Probability that the salesman sells some cars is %1.4f' % P)
# Out:
#  A) Probability that the salesman sells some cars is 0.9502

# %% [markdown]
# Probability that the salesman sells some cars is 0.9502

# %% [markdown]
# B) What is Probability that in a given week he will sell 2 or more but less than 5 cars?

# %%
# Let P1 be the probability that the salesman sells more than 4 cars
P1 = cumpoisson[4] # P(X >=4)
# Let P2 be the probability that the salesman sells more than 1 car
P2 = cumpoisson[1] # P(X >=1)
P = P1 - P2 # Prob. that the salesman will sell between 2 and 5 cars
print(' B) Probability that the salesman sells between 2 and 5 cars is %1.4f' % P)
# Out:
#  B) Probability that the salesman sells between 2 and 5 cars is 0.6161

# %% [markdown]
# Probabiliy that the salesman sells between 2 and 5 cars is 0.6161

# %% [markdown]
# C) Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week.

# %%
poisson = stats.poisson.cdf(n,rate) # To plot a graph with poisson distribution function
plt.plot(poisson,n, 'o-') 
plt.title('Poisson') # To display the Title of the plot as 'Poisson'
plt.xlabel('Cumulative Prob of cars sold per week') # To display the xlabel as 'Cumulative Prob of cars sold per week'
plt.ylabel('Number of cars sold per week') # To display the ylabel as 'Number of cars sold per week'
plt.show() # To display the plot

# %% [markdown]
# Q4. Accuracy in understanding orders for a speech based bot at a restaurant is important for the Company X which has designed, marketed and launched the product for a contactless delivery due to the COVID-19 pandemic. Recognition accuracy that measures the percentage of orders that are taken correctly is 86.8%. Suppose that you place an order with the bot and two friends of yours
# independently place orders with the same bot. Answer the following questions.
#
# A) What is the probability that all three orders will be recognized
# correctly?

# %%
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt

# %%
p   =  0.868 # Recognition Accuracy rate that the percentage of orders that are taken correctly is 86.8%
n   =  3 # sample size
k   =  np.arange(0,4) # An array of quantiles

# %%
binomial = stats.binom.pmf(k,n,p)

# %%
print(binomial)
# Out:
# [0.00229997 0.0453721  0.2983559  0.65397203]

# %%
print('A) Probability that all three orders will be recognized correctly? is %1.4f' %binomial[3])
# Out:
# A) Probability that all three orders will be recognized correctly? is 0.6540

# %% [markdown]
# Probability that all three orders will be recognized correctly is 0.6540

# %% [markdown]
# B) What is the probability that none of the three orders will be
# recognized correctly?

# %%
print('B) Probability that none of the three orders will be recognized correctly? is %1.4f' %binomial[0])
# Out:
# B) Probability that none of the three orders will be recognized correctly? is 0.0023

# %% [markdown]
# Probability that none of the three orders will be recognized correctly is 0.0023

# %% [markdown]
# C) What is the probability that at least two of the three orders will
# be recognized correctly?

# %% [markdown]
# Here, Need to calculate the cumulative probability.

# %%
cumbinomial = stats.binom.cdf(k,n,p)

# %%
print(cumbinomial)
# Out:
# [0.00229997 0.04767206 0.34602797 1.        ]

# %%
Q = 1- p # P(0)
P1 = p*p*Q 
Q1 = 3*P1
R = binomial[3] + Q1
print(Q, P1, Q1)
print(R)
# Out:
# 0.132 0.099451968 0.298355904
# 0.952327936

# %%
print('C) Two of the three orders will be recognized correctly? is %1.4f' %R)
# Out:
# C) Two of the three orders will be recognized correctly? is 0.9523

# %% [markdown]
# Probability of atleast two of the three orders will be recognized correctly is 0.9523

# %% [markdown]
# Q5. Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of Applied Statistics to get data driven business solution.

# %% [markdown]
# Ans. **Accuracy of Medical Test Reports for finding a disease using Bayes Theorem**
#
# Bayes Theorem can be used to determine the accuracy of medical test results by taking into consideration how any of the given person tested positive which shows person suffering with a disease and the person who is not suffering from a disease from the samples collected.
#
#
# * P(D) = probability that given test reports indicates how many are suffering from a disease (based on historical data)
# * P(P|D) = probability that test reports shows positive which shows how many are suffering from a disease from the samples collected.
# * P(ND) = probability that given test reports indicates how many are not suffering from a disease
# * P(P|ND) = probability that test reports shows negative which shows how many are not suffering from a disease from the samples collected.
#
# From Bayes Theorem,
#
#       We know that
#
#               P(D|P) = P(P|D)*P(D)/P(P)
#
#       We also know that the test results positive or negative are the mutual exclusively events
#
#               P(P) = P(P ∩ D) + P(P ∩ ND)
#
#      which in turn can be written as
#
#               P(D|P) = P(P|D) * P(P) / P(P|D) * P(P) + P(P|ND) * P(ND)
#
#
#  The data on the probabilities can be updated as we collect more and more samples in the above process. By setting a probability threshold, we can classify people who all are to be diagnonised. On getting the test results from samples collected is it positive or negative we can get the accuracy of the test reports for finding a disease.

# %% [markdown]
# **▶ PART - B**
#
# Q1. Read the data set, clean the data and prepare final dataset to be used for analysis.

# %% [markdown]
# 1. Import neccessary libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# 2. Import the data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/AI /Dec AI/Project - Applied Statistics/DS+-+Part2+-+Basketball.csv') # To read the data set 
df.shape # To get the no.of rows & columns in the data set
print(df.shape)
df.describe # To display the dataframe
# Out:
# (61, 13)
# <bound method NDFrame.describe of        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# ..      ...         ...   ...         ...      ...        ...       ...
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
# ...

# %% [markdown]
# 3. Seperate the numeric columns from the categorial columns

# %%
# select numerical columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
# select non-numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(df_numeric) # To print numeric values
print(df_non_numeric) # To print non-numeric or categorial values
# Out:
#     Tournament  HighestPositionHeld
# 0           86                    1
# 1           86                    1
# 2           80                    1
# 3           82                    1
# 4           86                    1
# ..         ...                  ...
# 56           1                   20
# 57           1                   16
# 58           1                   16
# 59           1                   15
# 60           1                    9
#
# [61 rows x 2 columns]
#        Team Score PlayedGames WonGames DrawnGames LostGames BasketScored  \
# 0    Team 1  4385        2762     1647        552       563         5947
# 1    Team 2  4262        2762     1581        573       608         5900
# 2    Team 3  3442        2614     1241        598       775         4534
# 3    Team 4  3386        2664     1187        616       861         4398
# 4    Team 5  3368        2762     1209        633       920         4631
# ...

# %%
# Check the datatypes of each attribute followed by the non-zero entry count
df.dtypes
# Out:
# Team                   object
# Tournament              int64
# Score                  object
# PlayedGames            object
# WonGames               object
# DrawnGames             object
# LostGames              object
# BasketScored           object
# BasketGiven            object
# TournamentChampion     object
# Runner-up              object
# TeamLaunch             object
# HighestPositionHeld     int64
# dtype: object

# %%
# Data Summary for all the attributes
df.describe(include='all').T
# Out:
#                     count unique     top freq      mean        std  min  25%  \
# Team                   61     61  Team 1    1       NaN        NaN  NaN  NaN
# Tournament           61.0    NaN     NaN  NaN      24.0  26.827225  1.0  4.0
# Score                  61     61    4385    1       NaN        NaN  NaN  NaN
# PlayedGames            61     53    2762    3       NaN        NaN  NaN  NaN
# WonGames               61     59       7    2       NaN        NaN  NaN  NaN
# DrawnGames             61     57      14    2       NaN        NaN  NaN  NaN
# LostGames              61     56      37    3       NaN        NaN  NaN  NaN
# BasketScored           61     60      70    2       NaN        NaN  NaN  NaN
# BasketGiven            61     61    3140    1       NaN        NaN  NaN  NaN
# TournamentChampion     61      8       -   52       NaN        NaN  NaN  NaN
# Runner-up              61     10       -   48       NaN        NaN  NaN  NaN
# ...

# %%
df.tail() # To fetch 5 last rows of the dataset
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  -         -    2009-10
# 57           37          57                  -         -    1956-57
# 58           51          85                  -         -    1951~52
# 59           34          65                  -         -    1955-56
# 60            -           -                  -         -    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %%
# Creating copy of the dataframe
df1=df.copy(deep = True)

# %% [markdown]
# 4. Clean the data set

# %%
# Replacing '-' with '0'
df1.replace('-', np.nan, inplace= True) 
df2 = df1.fillna(0)
print(df2)
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# ..      ...         ...   ...         ...      ...        ...       ...
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     0           0        0          0         0
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
# Convert Object datatype attributes to int
df2= df2.astype({"Score": np.int64, "PlayedGames": np.int64, "WonGames": np.int64, "DrawnGames": np.int64, "LostGames": np.int64,
                 "BasketScored": np.int64, "BasketGiven": np.int64, "TournamentChampion": np.int64, "Runner-up": np.int64})
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(11), object(2)
# memory usage: 6.3+ KB

# %%
from datetime import date 
def Year(x):
  if 'to' in x:
    return x.split('to')[0]
  elif '-' in x:
    return x.split('-')[0]
  elif '~' in x:
    return x.split('~')[0]
  elif '_' in x:
    return x.split('_')[0]
  else:
    return x

df2["LaunchYear"] = df2["TeamLaunch"].apply(Year)
df2 = df2.astype({"LaunchYear": np.int64}) # Convert LaunchYear attribute data type to int
today = date.today()
# Create a new column with the name as " Team Age " which will define the age of the team in years
df2["Team Age"] = df2["LaunchYear"].apply(lambda x: today.year-x) # Subtract the current year with TeamLaunch year to get age of the team
df2.head() # To fetch first 5 rows of the data frame
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up TeamLaunch  \
# 0          5947         3140                  33         23       1929
# 1          5900         3114                  25         25       1929
# 2          4534         3309                  10          8       1929
# 3          4398         3469                   6          6   1931to32
# 4          4631         3700                   8          7       1929
#
#    HighestPositionHeld  LaunchYear  Team Age
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
#  13  LaunchYear           61 non-null     int64
#  14  Team Age             61 non-null     int64
# dtypes: int64(13), object(2)
# ...

# %%
# Need to drop " TeamLaunch" column
df2.drop(['TeamLaunch'], axis=1, inplace=True)

# %%
df2.info() # To check whether " TeamLaunch" column gets dropped or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  HighestPositionHeld  61 non-null     int64
#  12  LaunchYear           61 non-null     int64
#  13  Team Age             61 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 6.8+ KB

# %% [markdown]
# Now, we have the final data set that is to be used for analysis.

# %% [markdown]
# Before moving on to the EDA, will create new attributes.
#
# *   **Basket_D** = Difference between 'BasketScored' & 'BasketGiven' per 'PlayedGames'
# *   **Win_P**= Percentage of 'WonGames' over 'PlayedGames'
# *   **PFin**= Percentage of Podium finishes('TournamentChampion'+'Runner-up')over 'Tournament'
# *   **SP**= 'Score' over 'PlayedGames'
# *   **TP**= Percentage of 'Tournament' over 'Team Age'

# %%
df2['Basket_D'] = (df2['BasketScored'] - df2['BasketGiven'])/df2['PlayedGames'].fillna(value=0)
df2['Win_P'] = df2['WonGames']/df2['PlayedGames'].fillna(value=0)*100
df2['PFin'] = df2['TournamentChampion'] + df2['Runner-up']/df2['Tournament']*100
df2['SP'] = df2['Score']/df2['PlayedGames'].fillna(value=0)
df2['TP'] = df2['Tournament']/df2['Team Age']*100

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  HighestPositionHeld  61 non-null     int64
#  12  LaunchYear           61 non-null     int64
#  13  Team Age             61 non-null     int64
#  14  Basket_D             60 non-null     float64
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Need to drop unnecessary columns
df2.drop(['BasketScored', 'BasketGiven', 'LostGames', 'WonGames', 'DrawnGames', 'TournamentChampion', 'Runner-up'], axis=1, inplace=True)
df2.describe()
# Out:
#        Tournament        Score  PlayedGames  HighestPositionHeld   LaunchYear  \
# count   61.000000    61.000000    61.000000            61.000000    61.000000
# mean    24.000000   901.426230   796.819672             7.081967  1958.918033
# std     26.827225  1134.899121   876.282765             5.276663    27.484114
# min      1.000000     0.000000     0.000000             1.000000  1929.000000
# 25%      4.000000    96.000000   114.000000             3.000000  1935.000000
# 50%     12.000000   375.000000   423.000000             6.000000  1951.000000
# 75%     38.000000  1351.000000  1318.000000            10.000000  1978.000000
# max     86.000000  4385.000000  2762.000000            20.000000  2017.000000
#
#         Team Age   Basket_D      Win_P       PFin         SP         TP
# count  61.000000  60.000000  60.000000  61.000000  60.000000  61.000000
# mean   64.081967  -0.369488  31.364790   3.350524   0.978535  33.074764
# ...

# %% [markdown]
# From the above data, it clearly indicates that 50% of the teams were launched in the last 71 years. There are 10 oldest teams which were launched in the year 1929. 50% of the teams have played only 55% of the tournaments since their launch.

# %%
# Plotting the distribution of HighestPositionHeld
sns.countplot(x='HighestPositionHeld',data=df2);
plt.legend();
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# Plot of teams against PFin using Barplot Seaborn as we are ploting the relationship between a numeric and a categoric variables. 
plt.figure(figsize=(12,3)) # figsize defines Width and Height of the parameters
df_tp=df2[df2['PFin']>0] 
sns.barplot(x=df_tp['Team'],y=df_tp['PFin'],palette = 'viridis');

# %% [markdown]
# Only 14 teams have ever finished as TournamentChampion or Runner-up. Team 1 & Team 2 are most successful with PFin > 50% of the Tournaments.

# %%
# Plot of HighestPostionHeld and Win_P
plt.figure(figsize=(12,3)) # figsize defines Width and Height of the parameters
df_tp=df2[df2['Win_P']>0] 
sns.scatterplot(x=df_tp['HighestPositionHeld'],y=df_tp['Win_P']);

# %% [markdown]
# Teams of the HighestPositionHeld <5 have the possibility of 30% of Win_P.

# %%
# Plot of HighestPostionHeld and TP
plt.figure(figsize=(12,3)) # figsize defines Width and Height of the parameters
df_tp=df2[df2['TP']>0] 
sns.scatterplot(x=df_tp['HighestPositionHeld'],y=df_tp['TP']);

# %% [markdown]
# As per the above plot, Teams that are partcipating regularly in the tournaments are having more chances to improve and to perform better for achieving highest positions.

# %%
# Split the data into groups based on the "HighestPositionHeld" 
df2.groupby(by='HighestPositionHeld').apply(display)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0    Team 1          86   4385         2762                    1        1929
# 1    Team 2          86   4262         2762                    1        1929
# 2    Team 3          80   3442         2614                    1        1929
# 3    Team 4          82   3386         2664                    1        1931
# 4    Team 5          86   3368         2762                    1        1929
# 5    Team 6          73   2819         2408                    1        1934
# 7    Team 8          70   2573         2302                    1        1929
# 9   Team 10          51   1884         1728                    1        1932
# 10  Team 11          45   1814         1530                    1        1941
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 0         94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1         94  1.008689  57.241130  54.069767  1.543085  91.489362
# ...

# %% [markdown]
# Clearly shows that only teams aged > 80 have finished first.Teams that have finished in Top 5 teams have all been >=59 years old.

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x=df2['HighestPositionHeld'],y=df2['Team Age'],linewidth=0.25)

# %% [markdown]
# On average, Teams can achieve higher positions in tournaments as they play more tournaments.

# %%
#print out the oldest teams
df2[df2['Team Age']==df2['Team Age'].max()]
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0    Team 1          86   4385         2762                    1        1929
# 1    Team 2          86   4262         2762                    1        1929
# 2    Team 3          80   3442         2614                    1        1929
# 4    Team 5          86   3368         2762                    1        1929
# 6    Team 7          82   2792         2626                    3        1929
# 7    Team 8          70   2573         2302                    1        1929
# 13  Team 14          44   1416         1428                    2        1929
# 44  Team 45           7    107          130                    3        1929
# 51  Team 52           4     56           72                    6        1929
# 53  Team 54           3     42           54                    8        1929
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# ...

# %%
#Identifying the teams that have played most games
df2.sort_values('PlayedGames',ascending=False).head(3)
# Out:
#      Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0  Team 1          86   4385         2762                    1        1929
# 1  Team 2          86   4262         2762                    1        1929
# 4  Team 5          86   3368         2762                    1        1929
#
#    Team Age  Basket_D      Win_P       PFin        SP         TP
# 0        94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1        94  1.008689  57.241130  54.069767  1.543085  91.489362
# 4        94  0.337075  43.772629  16.139535  1.219406  91.489362

# %% [markdown]
# Lets find the teams for recommendation to Company X. We will capture the top 3 best performing teams across multiple parameters for performance and collate the list.

# %%
#Defining a set to capture Potential Investment Candidates as derived through our analysis
candidates =set()

# %%
#Identifying Top 3 teams basis SP
df2.sort_values('SP',ascending=False).head(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0    Team 1          86   4385         2762                    1        1929
# 1    Team 2          86   4262         2762                    1        1929
# 20  Team 21          17    970          646                    2        1998
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 0         94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1         94  1.008689  57.241130  54.069767  1.543085  91.489362
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000

# %%
#Add these to candidates
candidates.update(df2.sort_values('SP',ascending=False).head(3)['Team'].unique())
candidates
# Out:
# {'Team 1', 'Team 2', 'Team 21'}

# %%
#Similarly checking the lowest ranked teams by SP
df2.sort_values('SP',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 54  Team 55           2     40           68                   16        1950
# 59  Team 60           1     14           30                   15        1955
# 60  Team 61           1      0            0                    9        2017
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 54        73 -1.647059  19.117647   0.0  0.588235   2.739726
# 59        68 -1.033333  16.666667   0.0  0.466667   1.470588
# 60         6       NaN        NaN   0.0       NaN  16.666667

# %% [markdown]
# Next let us identify the teams with maximum Basket_D

# %%
# Identifying Top 3 teams by greatest Basket_D
df2.sort_values('Basket_D',ascending=False).head(3)
# Out:
#      Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0  Team 1          86   4385         2762                    1        1929
# 1  Team 2          86   4262         2762                    1        1929
# 2  Team 3          80   3442         2614                    1        1929
#
#    Team Age  Basket_D      Win_P       PFin        SP         TP
# 0        94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1        94  1.008689  57.241130  54.069767  1.543085  91.489362
# 2        94  0.468630  47.475134  20.000000  1.316756  85.106383

# %% [markdown]
# Above table indicated Top teams. We will add that candidate to the list.
#
# Now, Lets consider the Win_P.

# %%
candidates.update(df2.sort_values('Basket_D',ascending=False).head(3)['Team'].unique())
# Similarly checking the lowest ranked tems by Basket_D
df2.sort_values('Basket_D',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 58  Team 59           1     19           30                   16        1951
# 54  Team 55           2     40           68                   16        1950
# 60  Team 61           1      0            0                    9        2017
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 58        72 -1.133333  23.333333   0.0  0.633333   1.388889
# 54        73 -1.647059  19.117647   0.0  0.588235   2.739726
# 60         6       NaN        NaN   0.0       NaN  16.666667

# %% [markdown]
# Team 59, Team 60, Team 61 are the teams have won more matches from which they have played.

# %%
# Identifying Top 3 teams by greatest Win_P
df2.sort_values('Win_P',ascending=False).head(3)
# Out:
#      Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0  Team 1          86   4385         2762                    1        1929
# 1  Team 2          86   4262         2762                    1        1929
# 2  Team 3          80   3442         2614                    1        1929
#
#    Team Age  Basket_D      Win_P       PFin        SP         TP
# 0        94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1        94  1.008689  57.241130  54.069767  1.543085  91.489362
# 2        94  0.468630  47.475134  20.000000  1.316756  85.106383

# %%
# Similarly checking the lowest ranked teams by Win_P
df2.sort_values('Win_P',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 54  Team 55           2     40           68                   16        1950
# 59  Team 60           1     14           30                   15        1955
# 60  Team 61           1      0            0                    9        2017
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 54        73 -1.647059  19.117647   0.0  0.588235   2.739726
# 59        68 -1.033333  16.666667   0.0  0.466667   1.470588
# 60         6       NaN        NaN   0.0       NaN  16.666667

# %%
# Identifying Top 3 teams by greatest PFin
df2.sort_values('PFin',ascending=False).head(3)
# Out:
#      Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 0  Team 1          86   4385         2762                    1        1929
# 1  Team 2          86   4262         2762                    1        1929
# 2  Team 3          80   3442         2614                    1        1929
#
#    Team Age  Basket_D      Win_P       PFin        SP         TP
# 0        94  1.016293  59.630702  59.744186  1.587618  91.489362
# 1        94  1.008689  57.241130  54.069767  1.543085  91.489362
# 2        94  0.468630  47.475134  20.000000  1.316756  85.106383

# %%
# Similarly checking the lowest ranked teams by PFin
df2.sort_values('PFin',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 33  Team 34           9    293          346                    7        1987
# 34  Team 35          11    285          334                    4        1941
# 60  Team 61           1      0            0                    9        2017
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 33        36 -0.572254  27.745665   0.0  0.846821  25.000000
# 34        82 -0.505988  30.838323   0.0  0.853293  13.414634
# 60         6       NaN        NaN   0.0       NaN  16.666667

# %%
candidates
# Out:
# {'Team 1', 'Team 2', 'Team 21', 'Team 3'}

# %% [markdown]
# Let's consider the correlation between the data & check whether any of the parameter correlates to PFin, TournamentChampion, HighestPostionHeld

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2.corr(),annot=True)

# %%
# Creating a temporary dataframe for easier plotting
df2_temp=df2[['Team','Tournament','SP','Basket_D','Team Age','Win_P','PFin','HighestPositionHeld','TP']]

# %%
sns.pairplot(df2_temp)

# %% [markdown]
# Following observations from the correlation heat-map and the pair-plots are listed below:
#
# * HighestPositionHeld is inversely correlated with Win_P, Basket_D, PFin, SP & TP.
# * PFin is inversely correlated with Win_P, SP, Basket_D.
# * Teams get older than 40 are the ones that have achieved HighestPositionHeld < five(except one).They also have the best Win_P and PFin and played most tournaments.
# * As teams play more games (PlayedGames/Tournament) the chances of success (HighestPositionHeld/PFin) also increase, which is understandable as the teams will get better and adapt to the tournament better with exposure.
# * Basket_D is >0 for teams that have held high positions or finished on the podium atleast once
# * Teams with HighestPositionHeld < 5 tend to have SP > 10
# * There are many teams that, though were launched in the early years have not played as many tournaments. We see that higher the TP, higher the Win_P, Basket_D and PFin. This implies regular participation in the tournament is essential to success.
# * Among teams with Team Age < 50, there are very few there is only 1 team which has held finished in Top 5 ever but a good number of teams have finished in Top 10.

# %% [markdown]
# Hence, for our recommendation process flow, we note that
#
# * Characterstics are distinct for older and newer teams. Never teams take time to achieve high positions on the table. Hence, our approach should be different for older teams and emerging teams.
# * Also, we see that chances of success increase with more games. We should track teams who play regularly in the tournament. Hence, we should establish a cut-off on the TP as well.

# %%
# Checking thebox plot for Age & PlayedGames
fig,ax = plt.subplots(1,2)

fig.set_figheight(5)
fig.set_figwidth(10)

sns.boxplot(df2['Team Age'],ax=ax[0])
sns.boxplot(df2['TP'],ax=ax[1])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(x=df2['Team Age'],y=df2['TP'])

# %%
# Plotting a disturbution of Team Age
plt.figure(figsize=(10,5))
df2['Team Age'].plot.hist(bins=100)

# %% [markdown]
# **For Older Teams:**
#
# Age Upper Cut-Off = 93.0(max.value; as distribution is spread out except for the teams aged 93)
#
# Age Lower Cut-Off = 43.0 (median)
#
# Tour Percent Lower Cut-Off = 25% (median)
#
# HighestPositionHeld Cut-Off = 6 (median)

# %% [markdown]
# With this we will create a subset of our dataset and proceed with further analysis.

# %%
sns.scatterplot(x=df2['Team Age'],y=df2['TP'])
plt.axhline(25,linewidth = 1, color='red') # TP cut-off
plt.axvline(92,linewidth=1,color='red') # Age upper cut-off
plt.axvline(43,linewidth=1,color='red') # Age lower cut-off

# %%
# Creating a subset of our dataset
# df3= df2[(df2['YearLaunch']>1929) & (df2['YearLaunch']<1981)]

# %%
df3 = df2[(df2['Team Age']<92) & (df2['Team Age']>43) & (df2['TP']>25) & (df2['HighestPositionHeld'])]
df3
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 5    Team 6          73   2819         2408                    1        1934
# 9   Team 10          51   1884         1728                    1        1932
# 10  Team 11          45   1814         1530                    1        1941
# 17  Team 18          38   1174         1192                    3        1933
# 18  Team 19          27   1148          988                    3        1960
# 23  Team 24          21    606          678                    5        1959
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 5         89  0.127492  41.112957   6.479452  1.170681  82.022472
# 9         91 -0.192708  35.069444   1.000000  1.090278  56.043956
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049
# 17        90 -0.259228  34.228188   0.000000  0.984899  42.222222
# 18        63 -0.191296  33.704453   0.000000  1.161943  42.857143
# ...

# %% [markdown]
# **For Emerging Teams:** For teams aged < 43, let us check if we missed any potential teams that have played tournaments regularly and secured top 10 atleast once (we can be lineient on HighestPositionHeld since we know that younger teams time to establish themselves.

# %% [markdown]
# Age Upper cut-off = 43.0 (median)
#
# Tour percent lower cut-off = 25% (median)
#
# HighestPositionHeld cut-off = 10 (75%il)
#
#
# With this we will create a subset of our dataset and proceed with futher analysis.

# %%
# Age cut-off
df2[(df2['Team Age']<=43) & (df2['TP']>25) & (df2['HighestPositionHeld']<=10)]
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 20  Team 21          17    970          646                    2        1998
# 24  Team 25          12    553          456                    6        2004
# 36  Team 37           6    242          228                    8        2007
# 43  Team 44           3    132          114                   10        2014
#
#     Team Age  Basket_D      Win_P      PFin        SP         TP
# 20        25  0.159443  41.176471  5.882353  1.501548  68.000000
# 24        19 -0.247807  32.236842  0.000000  1.212719  63.157895
# 36        16 -0.535088  27.192982  0.000000  1.061404  37.500000
# 43         9 -0.245614  30.701754  0.000000  1.157895  33.333333

# %% [markdown]
# We see that these teams have good participation rates since their launch along with high SP and is potential candidate.since it has Basket_D>0, Win_P>30% and PFin > 0. Since there are only 5, instead of performing separate analysis, we can include them with our dataframe for older-teams for analysis. Let us include these in our dataframe.

# %%
#Emerging teams into dataset
df3=df3.append(df2[(df2['Team Age']<=43) & (df2['TP']>25) & (df2['HighestPositionHeld']<=10)])
df3
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 5    Team 6          73   2819         2408                    1        1934
# 9   Team 10          51   1884         1728                    1        1932
# 10  Team 11          45   1814         1530                    1        1941
# 17  Team 18          38   1174         1192                    3        1933
# 18  Team 19          27   1148          988                    3        1960
# 23  Team 24          21    606          678                    5        1959
# 20  Team 21          17    970          646                    2        1998
# 24  Team 25          12    553          456                    6        2004
# 36  Team 37           6    242          228                    8        2007
# 43  Team 44           3    132          114                   10        2014
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# ...

# %% [markdown]
# **Candidate Selection**
#
# Let us go back to our candidates list and see if they pass the criteria set above

# %%
# Check if candidates identified earlier meet the criteria
df3[df3['Team'].isin(candidates)]
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 20  Team 21          17    970          646                    2        1998
#
#     Team Age  Basket_D      Win_P      PFin        SP    TP
# 20        25  0.159443  41.176471  5.882353  1.501548  68.0

# %% [markdown]
# Only Team 21 meet the criteria. We can retain it and remove the rest. Then we will adopt the same process we followed earlier to identify candidates

# %%
candidates=set(df3[df3['Team'].isin(candidates)]['Team'].values)

# %%
# Identifying top 3 teams by SP & updating candidates
df3.sort_values(by='SP',ascending=False).head(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 20  Team 21          17    970          646                    2        1998
# 24  Team 25          12    553          456                    6        2004
# 10  Team 11          45   1814         1530                    1        1941
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000
# 24        19 -0.247807  32.236842   0.000000  1.212719  63.157895
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049

# %%
candidates.update(df3.sort_values(by='SP',ascending=False).head(3)['Team'])
# Identifying highest Win_P, Basket_D & PFin teams & updating candidates
df3.sort_values(by='Win_P',ascending=False).head(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 20  Team 21          17    970          646                    2        1998
# 5    Team 6          73   2819         2408                    1        1934
# 10  Team 11          45   1814         1530                    1        1941
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000
# 5         89  0.127492  41.112957   6.479452  1.170681  82.022472
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049

# %%
candidates.update(df3.sort_values(by='Win_P',ascending=False).head(3)['Team'])
df3.sort_values(by='Basket_D',ascending=False).head(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 20  Team 21          17    970          646                    2        1998
# 5    Team 6          73   2819         2408                    1        1934
# 10  Team 11          45   1814         1530                    1        1941
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000
# 5         89  0.127492  41.112957   6.479452  1.170681  82.022472
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049

# %%
candidates.update(df3.sort_values(by='Basket_D',ascending=False).head(3)['Team'])
df3.sort_values(by='PFin',ascending=False).head(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 10  Team 11          45   1814         1530                    1        1941
# 5    Team 6          73   2819         2408                    1        1934
# 20  Team 21          17    970          646                    2        1998
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049
# 5         89  0.127492  41.112957   6.479452  1.170681  82.022472
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000

# %%
candidates.update(df3.sort_values(by='PFin',ascending=False).head(3)['Team'])
# Identying lowest Win_P, Basket_D, PFin & SP teams & updating candidates
df3.sort_values(by='Win_P',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 43  Team 44           3    132          114                   10        2014
# 23  Team 24          21    606          678                    5        1959
# 36  Team 37           6    242          228                    8        2007
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 43         9 -0.245614  30.701754   0.0  1.157895  33.333333
# 23        64 -0.401180  29.941003   0.0  0.893805  32.812500
# 36        16 -0.535088  27.192982   0.0  1.061404  37.500000

# %%
df3.sort_values(by='PFin',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 24  Team 25          12    553          456                    6        2004
# 36  Team 37           6    242          228                    8        2007
# 43  Team 44           3    132          114                   10        2014
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 24        19 -0.247807  32.236842   0.0  1.212719  63.157895
# 36        16 -0.535088  27.192982   0.0  1.061404  37.500000
# 43         9 -0.245614  30.701754   0.0  1.157895  33.333333

# %%
df3.sort_values(by='SP',ascending=False).tail(3)
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 36  Team 37           6    242          228                    8        2007
# 17  Team 18          38   1174         1192                    3        1933
# 23  Team 24          21    606          678                    5        1959
#
#     Team Age  Basket_D      Win_P  PFin        SP         TP
# 36        16 -0.535088  27.192982   0.0  1.061404  37.500000
# 17        90 -0.259228  34.228188   0.0  0.984899  42.222222
# 23        64 -0.401180  29.941003   0.0  0.893805  32.812500

# %%
# Who are the candidate at the moment?
candidates
# Out:
# {'Team 11', 'Team 21', 'Team 25', 'Team 6'}

# %% [markdown]
# Let us look at the data once again for our candidate teams

# %%
df3_t=df3[df3['Team'].isin(candidates)]
df3_t
# Out:
#        Team  Tournament  Score  PlayedGames  HighestPositionHeld  LaunchYear  \
# 5    Team 6          73   2819         2408                    1        1934
# 10  Team 11          45   1814         1530                    1        1941
# 20  Team 21          17    970          646                    2        1998
# 24  Team 25          12    553          456                    6        2004
#
#     Team Age  Basket_D      Win_P       PFin        SP         TP
# 5         89  0.127492  41.112957   6.479452  1.170681  82.022472
# 10        82 -0.088889  36.797386  12.111111  1.185621  54.878049
# 20        25  0.159443  41.176471   5.882353  1.501548  68.000000
# 24        19 -0.247807  32.236842   0.000000  1.212719  63.157895

# %% [markdown]
# We have shortlisted candidates. These teams satisfy our observations from the pair plot. All have Win_P>30 , SP>1.0 and PFin>0 except Team 25 which is an emerging team. Basket_D>0 for all except two teams.

# %%
print("Final candidate", candidates)
# Out:
# Final candidate {'Team 11', 'Team 25', 'Team 21', 'Team 6'}

# %% [markdown]
# **Recommendation:** Our recommedations to Company X is to invest in any of the above teams. Teams 21 and 25 are emerging teams which have future potential. Teams 4, 6 and 11 are relatively older but best performers on multiple attributes.

# %% [markdown]
# **Observations on the datapoints collected to perform a better data analysis**

# %% [markdown]
# **Quality:**

# %% [markdown]
# * Pre-processed data will help save time for analysis (such as launch year without combinations, the derived attributes used in the calculation, using the right data type for storage)
# * Additional data points such as Team Budgets, Head to Head records, individual match data for tournaments, Fan base, Time Since Last Appearance in tournament are useful attributes that can be captured
# * Tournament level data such as the position attained in eachh tournament in chronological order will help with accounting for recent form

# %% [markdown]
# **Quantity:**

# %% [markdown]
# * For any metric there are only 61 data points available. If we take a cut on any attribute then there are very few datapoints left to do any significance analysis
# * The data could be made richer by adding individual match data from each of the tournaments

# %% [markdown]
# **Variety:**

# %% [markdown]
# * Data from a variety of sources such as P&L statements, could be tracked to update our database.
# * Specifically data on Social Media fan following, Budget, etc could help assess the customer reach an Rol that company X can target.
# * Data from specialist Basketball analytics companies such as Opta could be incorporated into this to add more attributes for analysis.

# %% [markdown]
# **Veracity:**

# %% [markdown]
# * For a Basketball dataset, there are very high number of drawn games. This questions the authencity of the data.
# * For Team 23, the PlayedGames does not equal the sum of games won, drawn and lost. This again, makes us doubt the veracity of the data.

# %% [markdown]
# **Value:**

# %% [markdown]
# * If we are able to implement the above sucessfully. we can add value by being able to predict which teams among the candidates is best by comparing Head to Head performances and recent trends.
# * We will be able to predict energing teams better if we have the information on trends and years since last appearances in the tournment.

# %% [markdown]
# 3.Q)
# 1. Read the CSV file

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
# import the dataset
from google.colab import drive
drive.mount('/content/drive') 

df = pd.read_csv('/content/drive/MyDrive/AI /Dec AI/Project - Applied Statistics/DS+-+Part3+-+CompanyX_EU.csv') # To read the data set 
df.shape # To get the no.of rows & columns in the data set
print(df.shape)
df.describe # To display the dataframe
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (662, 6)
# <bound method NDFrame.describe of              Startup             Product Funding             Event  \
# 0             2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1               3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2        3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3         3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4    42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
# ..               ...                 ...     ...               ...
# 657           Zivity          zivity.com     $8M         TC40 2007
# 658           Zmorph        zmorph3d.com     $1M                 -
# 659           Zocdoc          zocdoc.com   $223M         TC40 2007
# 660             Zula         zulaapp.com   $3.4M   Disrupt SF 2013
# ...

# %%
df.head() # To fetch first 5 rows of the data frame
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %%
# Check the number of entries in dataset
df.shape
# Out:
# (662, 6)

# %%
# Data type of each attribute
df.dtypes
# Out:
# Startup           object
# Product           object
# Funding           object
# Event             object
# Result            object
# OperatingState    object
# dtype: object

# %% [markdown]
# All the attributes are of object datatypes. We will need to convert the Funding attribute to numeric value

# %%
# Checking for missing values
df.isna().sum()
# Out:
# Startup             0
# Product             6
# Funding           214
# Event               0
# Result              0
# OperatingState      0
# dtype: int64

# %% [markdown]
# There are 6 entries missing under Product attribute and 214 entries missing under Funding

# %% [markdown]
# **Data Preprocessing & Visualization**

# %%
# Dropping therows which have no data
df1 = df.dropna().copy(deep=True)
df1.shape
# Out:
# (446, 6)

# %% [markdown]
# The entries in the Funding attribute are of 3 types.
#
# a) in $M
#
# b) in $K
#
# c) in $B
#
# We need to convert these to a standard scale in $M with only numeric value stored in the column.

# %%
df1.loc[:,'Funds_in_million'] = df1['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))

# %%
df1.head(5)
# Out:
#          Startup          Product Funding                      Event  \
# 1           3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 3     3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 5           5to1         5to1.com  $19.3M                  TC50 2009
# 6   8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 10    AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
#
#              Result OperatingState  Funds_in_million
# 1        Contestant         Closed              0.63
# 3   Audience choice      Operating              1.00
# 5        Contestant       Acquired             19.30
# 6          Finalist      Operating             29.00
# 10       Contestant      Operating              1.80

# %%
df1.shape
# Out:
# (446, 7)

# %%
# Boxplot for Funds in Mn
plot = plt.boxplot(df1.Funds_in_million)
plt.title('Boxplot of the funds')
plt.ylabel("Funs raised(in Million)")

plt.show()

# %% [markdown]
# The lower Fence here is $0.005M. We can also obtain it through the below.

# %%
lower_fence = plot['caps'][0].get_data()[1][1] # Can use the values from the boxplot itself
lower_fence
# Out:
# 0.005

# %%
upper_fence = plot['caps'][1].get_data()[1][1] # Can use the values from the boxplot itself
upper_fence
# Out:
# 22.0

# %%
# Finding the number of outliers beyond the upper fence
print(f'Number of outliers = {len(df1[df1.Funds_in_million > upper_fence])}')
# Out:
# Number of outliers = 60

# %%
# Details of companies that are outliers on Funds_in_million
df1[df1.Funds_in_million > upper_fence]
# Out:
#                Startup               Product  Funding  \
# 6         8 Securities       8securities.com     $29M
# 31             Anyclip           anyclip.com     $24M
# 40               Artsy             artsy.net   $50.9M
# 49          Badgeville        badgeville.com     $40M
# 56          Betterment        betterment.com    $205M
# 108          Clickable         clickable.com   $32.5M
# 113         Cloudflare        cloudflare.com  $182.1M
# 128      Credit Sesame      creditsesame.com   $35.4M
# 130   CrowdFlower Inc.       crowdflower.com     $38M
# 132      Cubic Telecom      cubictelecom.com   $37.1M
# 138           DataSift          datasift.com     $72M
# 139             DataXu            dataxu.com     $64M
# 154            Dropbox           dropbox.com    $1.7B
# 166             Enigma             enigma.io   $34.6M
# 172       EverythingMe         everything.me   $35.5M
# 179            Famo.us               famo.us   $30.1M
# ...

# %%
# Dropping the entries where Funds_in_million is higher than upper_fence
df1.drop(df1[df1['Funds_in_million']>upper_fence].index, inplace=True)

# %%
plot = plt.boxplot(df1['Funds_in_million'])
plt.title('Boxplot of funds without the original outliers')
plt.ylabel("Funds raised in Million")
plt.show()

# %%
# Checking the frequency of Operting State features
df1['OperatingState'].value_counts()
# Out:
# Operating    275
# Closed        56
# Acquired      55
# Name: OperatingState, dtype: int64

# %%
sns.countplot(df1['OperatingState'])
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Plotting a distribution of Funds_in_million
sns.distplot(df1['Funds_in_million'],bins=30,kde=True)
plt.title('Distribution of Funds_in_million')
plt.xlabel('Funds_in_million')
plt.ylabel('Frequency')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Statistical Analysis**

# %%
df1['Funds_in_million'].describe()
# Out:
# count    386.00000
# mean       3.72514
# std        4.73236
# min        0.00500
# 25%        0.60000
# 50%        1.70000
# 75%        5.00000
# max       22.00000
# Name: Funds_in_million, dtype: float64

# %% [markdown]
# Although the range of values for Funds_in_million are from $0.005Mn  to $22.0Mn, 75% of the startups have funding < $5.0Mn. The data remains skewed despite removing outliers.

# %%
# Plotting the funds distribution for companies Operating and Closed
fig,ax = plt.subplots(1,2)

fig.set_figheight(10)
fig.set_figwidth(20)
sns.distplot(x=df1[df1['OperatingState']=='Operating']['Funds_in_million'],ax=ax[0])
sns.distplot(x=df1[df1['OperatingState']=='Closed']['Funds_in_million'],ax=ax[1])
ax[0].set_title("Funding for companies Operating")
ax[1].set_title("Funding for companies Closed")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The distributions look very similar on the plot. However,to test the statistical significance, we will do statistical test using either Z-test or T-test as distributions are not normal, since our sample size > 30.

# %% [markdown]
# **Ho**=Null Hypothesis = There is no difference between two means(Mean of funds raised by Operating and Closed)
#
# **Ha**= Alternate Hypothesis = There is a sigificant difference between two means(Mean of funds raised by Operating and Closed)

# %% [markdown]
# Now, let us perform the Z-Test on this sample on this sample at 0.05 significance level.

# %%
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest
alpha = 0.05 #defining the significance level
operating = df1[df1['OperatingState']=='Operating']['Funds_in_million']
closed = df1[df1['OperatingState']=='Closed']['Funds_in_million']
z_stat, p_val = ztest(operating, closed)

if p_val > alpha:
  print("Since p_val = %.3f is greater than the siginificant level (0.05), the difference between the means not significant and we fail to reject Ho" %p_val)
else:
  print("Since p_val = %.3f is less than the siginificant level (0.05), the difference between the means not significant" %p_val)
# Out:
# Since p_val = 0.192 is greater than the siginificant level (0.05), the difference between the means not significant and we fail to reject Ho

# %%
# Using T-test also gives the same result
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(operating, closed)

if p_val > alpha:
  print("Since p_val = %.3f is greater than the siginificant level (0.05), the difference between the means not significant and we fail to reject Ho" %p_val)
else:
  print("Since p_val = %.3f is less than the siginificant level (0.05), the difference between the means not significant" %p_val)
# Out:
# Since p_val = 0.193 is greater than the siginificant level (0.05), the difference between the means not significant and we fail to reject Ho

# %%
# Make a copy of the dataframe
df2 = df1.copy(deep=True)
df2.head() # To fetch first 5 rows of the dataframe
# Out:
#        Startup         Product Funding                      Event  \
# 1         3DLT        3dlt.com   $630K           Disrupt NYC 2013
# 3   3Dprintler  3dprintler.com     $1M            Disrupt NY 2016
# 5         5to1        5to1.com  $19.3M                  TC50 2009
# 10  AdhereTech  adheretech.com   $1.8M  Hardware Battlefield 2014
# 11    AdRocket    adrocket.com     $1M                  TC50 2008
#
#              Result OperatingState  Funds_in_million
# 1        Contestant         Closed              0.63
# 3   Audience choice      Operating              1.00
# 5        Contestant       Acquired             19.30
# 10       Contestant      Operating              1.80
# 11       Contestant         Closed              1.00

# %%
# Check the frequency distribution of the result variables
df2.Result.value_counts()
# Out:
# Contestant         282
# Finalist            52
# Audience choice     20
# Winner              17
# Runner up           15
# Name: Result, dtype: int64

# %%
sns.countplot(df2['Result'])
plt.xticks(rotation=90); # To rotate the ticks labels at the x-axis with an angle of 90 degrees
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# There are 282 contenstants while rest are either Finalists , Audience choice, Winner , RunnerUps. Now, we will classify all except contestants as winners.

# %%
# Finding proportion of winners and contestants that are in 'Operating' state
# To get total number of winners
n_winners = df2['Result'].value_counts()[1:].sum() 
# To get total number of contestants
n_contestants = df2['Result'].value_counts()[0]

n_w_o = df2['OperatingState'][df2['Result']!= 'Contestant'].value_counts()[0]
n_c_o = df2['OperatingState'][df2['Result']== 'Contestant'].value_counts()[0]

print("Proportion of Winners that are Operating is %.3f" %(n_w_o/n_winners))
print("Proportion of Contestants that are Operating is %.3f" %(n_w_o/n_contestants))
# Out:
# Proportion of Winners that are Operating is 0.779
# Proportion of Contestants that are Operating is 0.287

# %% [markdown]
# We see that the proportions are different but to determine if they are statiscally different. We will perform Z-test or Chi-square test.

# %% [markdown]
# **Ho**= Null Hypothesis = The proportion of companies that are operating is the same in both winners and contestants
#
# **Ha**= Alternate Hypothesis = The proportion of companies that are operating statistically different between winners and contestansts

# %% [markdown]
# Lets, perform Z-test on this sample at 0.05 significance level

# %%
from statsmodels.stats.proportion import proportions_ztest

z_test, p_val = proportions_ztest([n_w_o,n_c_o],[n_winners,n_contestants])

if p_val > alpha:
  print("Since p_val = %.3f is greater than the siginificant level (0.05), the difference between the means are significant and we will fail to reject Ho" %p_val)
else:
  print("Since p_val = %.3f is greater than the siginificant level (0.05), the difference between the means are significant" %p_val)
# Out:
# Since p_val = 0.080 is greater than the siginificant level (0.05), the difference between the means are significant and we will fail to reject Ho

# %%
# Checking Distribution of Event variable
df1['Event'].value_counts()
# Out:
# TC50 2008                    25
# TC40 2007                    22
# Disrupt NY 2015              21
# Disrupt NYC 2013             19
# Disrupt SF 2011              19
# Disrupt SF 2013              19
# Disrupt SF 2014              19
# Disrupt NYC 2012             19
# TC50 2009                    19
# Disrupt SF 2015              19
# Disrupt SF 2016              17
# Disrupt NY 2016              16
# Disrupt SF 2012              15
# Disrupt NYC 2014             15
# Disrupt NYC 2011             15
# Disrupt SF 2010              13
# Hardware Battlefield 2016    12
# Hardware Battlefield 2014    12
# Disrupt London 2015          11
# Hardware Battlefield 2015    10
# Disrupt NYC 2010             10
# Disrupt London 2016          10
# Disrupt EU 2014              10
# Disrupt EU 2013               9
# -                             6
# Disrupt Beijing 2011          4
# Name: Event, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df1['Event']) # To plot the countplot of Event variable
plt.xticks(rotation=90); # To rotate the ticks labels at the x-axis with an angle of 90 degrees
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Picking only the entries with Disrupt keyword in Event and conducted from 2013 onwards
events = df1[df1['Event'].apply( lambda x: 'Disrupt' in x and int(x[-4:]) > 2012)]['Event']
year = events.apply(lambda x: int(x[-4:])) # To pick only the entries with years > 2012
print(events) # To print events with Disrupt keyword and conducted from 2013 onwards
print(year) # To print event years conducted from 2013 onwards
# Out:
# 1         Disrupt NYC 2013
# 3          Disrupt NY 2016
# 13         Disrupt SF 2015
# 14     Disrupt London 2016
# 16         Disrupt SF 2015
#               ...
# 635        Disrupt NY 2015
# 641       Disrupt NYC 2013
# 642        Disrupt SF 2014
# 646    Disrupt London 2015
# 660        Disrupt SF 2013
# Name: Event, Length: 185, dtype: object
# 1      2013
# 3      2016
# 13     2015
# 14     2016
# 16     2015
#        ...
# 635    2015
# 641    2013
# 642    2014
# 646    2015
# 660    2013
# Name: Event, Length: 185, dtype: int64

# %%
NY_eve = df1.loc[events[events.apply(lambda x: 'NY' in x)].index, 'Funds_in_million'] # To fetch the events under NY keyword
SF_eve = df1.loc[events[events.apply(lambda x: 'SF' in x)].index, 'Funds_in_million'] # To fetch the events under SF keyword
EU_eve = df1.loc[events[events.apply(lambda x: 'EU' in x or 'London' in x)].index, 'Funds_in_million'] # To fetch the events under EU keyword
print("NY events: %i SF events: %i EU events: %i" %(len(NY_eve),len(SF_eve),len(EU_eve))) # To print the lengths of events under NY,SF,EU
# Out:
# NY events: 71 SF events: 74 EU events: 40

# %% [markdown]
# The lengths of the events are calculated seperately.
#
# Length of NY events is 71
#
# Length of SF events is 74
#
# Length of EU events is 40

# %%
plt.figure(figsize=(15,6)) # To plot the graph with desired size as (15,6)
sns.distplot(NY_eve, color = 'purple', label = 'NY') # To plot the distplot for NY events with colur 'purple' and label 'NY'
sns.distplot(SF_eve, color = 'orange', label = 'SF') # To plot the distplot for SF events with colur 'orange' and label 'SF'
sns.distplot(EU_eve, color = 'green', label = 'EU')  # To plot the distplot for EU events with colur 'green' and label 'EU'
plt.legend() # To display the legends for three events NY,SF,EU
plt.show() # To display the distplots of three events
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Observations:**
#
# *   Visually the distributions are looking similar
# *   The Modes of the three distributions are almost same
# *   Dispersion in NY is high when compared with others
